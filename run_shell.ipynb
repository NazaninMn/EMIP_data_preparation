# %%
# !pwd
c

# %%
# !python main.py
# Out:
# python: can't open file 'main.py': [Errno 2] No such file or directory

# %%
from PIL import Image
import numpy as np
np.array(Image.open('/scratch/nm4wu/AHA/Data/data_classification/nuclei_channel/86634_16.png')).shape
# Out:
# (2048, 2048)

# %%
import numpy as np
import matplotlib.pyplot as plt

a= np.load('/scratch/nm4wu/AHA/data_for_train/OL/Hovernet_data/86650_17_27.npy')

plt.imshow(a[:,:,:3])
plt.show()

# %%
plt.imshow(a[:,:,5])
plt.show()
