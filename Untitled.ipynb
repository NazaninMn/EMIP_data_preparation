# %%
# !pwd
# Out:
# /scratch/nm4wu/AHA/prepare_data_hover_v2

# %%
cd /scratch/nm4wu/AHA/prepare_data_hover_v2
# Out:
# /scratch/nm4wu/AHA/prepare_data_hover_v2

# %%
# !python main.py
# Out:
# => Using random seed 1234
# =============== training: ratio=1.00 ===============
# => Preparing training samples
# Generating Voronoi label from point label...
# 	11/11
# Generating Voronoi label from point label...
# Generating Voronoi label from point label...
# 	2/2
# Generating cluster label from point label...
# 	11/11
# Generating cluster label from point label...
# Generating cluster label from point label...
# 	2/2
# Generating cluster label from point label...
# 	11/11
# Generating cluster label from point label...
# Generating cluster label from point label...
# 	2/2
# Spliting large images into small patches...
# /scratch/nm4wu/AHA/prepare_data_hover_v2/prepare_data.py:546: UserWarning: ../data/OL_LGALS3/patches/images/86633_16_0.png is a low contrast image
#   io.imsave('{:s}/{:s}_{:d}.png'.format(save_dir, name, k), seg_imgs[k])
# ...

# %%
from PIL import Image
import numpy as np
np.array(Image.open('/scratch/nm4wu/AHA/Data/data_classification/nuclei_channel/86634_16.png')).shape
# Out:
# (2048, 2048)

# %%
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
a =np.load('/scratch/nm4wu/AHA/Image_classification/OL/labels_point/3D/86647_17_label_point.npy')
a = gaussian_filter(a[:,:,9], sigma=5)
plt.imshow(a)
plt.show()

# %%
g_mask = gaussian_filter(mask_2D, sigma=5)
